# %%
# you must populate this dict with the schools required -> try talking to the teaching team about this


schools = {   
'le-wagon' : 10868,
'udacity' : 11118,
'ironhack' : 10828,
'app-academy' : 10525,
'general-assembly' : 10761,
'hackwagon-academy' : 10792,
'nucamp' : 10923,
'springboard' : 11035,  
#'coding-dojo' : 10659,
#'bloc': 10558,
#'shecodes': 11014,
#'thinkful' : 11098, 
#'nyc-data-science-academy' : 10925,
#'makers-academy' : 10874,
#'greyatom-school-of-data-science' : 10776,
#'actualize' : 10505,
#'codesmith' : 10643,
#'the-tech-academy' : 11091,
#'designlab' : 10697,
#'product-gym' : 10959,
#'dataquest' : 10683,
#'flatiron-school' : 10748,
#'hack-reactor' : 10788,
#'juno-college-of-technology' : 10787,
#'product-school' : 10960,
#'brainstation' : 10571,
}

import re
import pandas as pd
from pandas.io.json import json_normalize
import requests



def get_comments_school(school):
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])
  
    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
# could you write this as a list comprehension? ;)
comments = []

for school in schools.keys():
    print(school)
    comments.append(get_comments_school(school))

comments = pd.concat(comments)
# Out:
# le-wagon
# udacity
# ironhack
# app-academy
# general-assembly
# hackwagon-academy
# nucamp
# springboard

# %%
# Raw comments (the code is as given - no change was made)


comments
# Out:
#          id                 name  anonymous hostProgramName  graduatingYear  \
# 0    270744         Sharon Sheah      False            None          2020.0
# 1    270738         julien ergan      False            None          2020.0
# 2    270579  Sarin Boivin Picard      False            None          2020.0
# 3    270510     Eirik Lysenstoen      False            None          2020.0
# 4    270151      Vincent Leblanc      False            None          2020.0
# ..      ...                  ...        ...             ...             ...
# 726  234894         Stephanie S.      False            None          2015.0
# 727  234877             Joe Fang      False            None          2015.0
# 728  234838                Zeina      False            None          2016.0
# 729  242681                 Jean      False            None          2016.0
# 730  234178                  Ben      False            None          2016.0
#
#     isAlumni                         jobTitle  \
# ...

# %%
# The code is as given - no change was made

from pandas.io.json import json_normalize

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])
    
    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school
    

    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d = get_school_info(school,id)
    
    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# le-wagon
# <ipython-input-4-5204565eee01>:16: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   locations_df = json_normalize(locations)
# udacity
# ironhack
# app-academy
# general-assembly
# hackwagon-academy
# nucamp
# springboard

# %%
# Raw locations_list (the code is as given - no change was made)

locations_list
# Out:
# [       id                  description  country.id          country.name  \
#  0   15803         Melbourne, Australia          20             Australia
#  1   15904          Casablanca, Morocco          44               Morocco
#  2   15906      Buenos Aires, Argentina          60             Argentina
#  3   15964            Brussels, Belgium          46               Belgium
#  4   15979                 Milan, Italy          39                 Italy
#  5   15996               Chengdu, China          15                 China
#  6   16039          Mexico City, Mexico          29                Mexico
#  7   16049       Amsterdam, Netherlands          59           Netherlands
#  8   16106            Sao Paulo, Brazil          42                Brazil
#  9   16124             Barcelona, Spain          12                 Spain
#  10  16145             Bordeaux, France          38                France
#  11  16146          Copenhagen, Denmark          47               Denmark
# ...

# %%
# Raw locations (the code is as given - no change was made)

locations = pd.concat(locations_list)
locations.head()
# Out:
#       id              description  country.id country.name country.abbrev  \
# 0  15803     Melbourne, Australia        20.0    Australia             AU
# 1  15904      Casablanca, Morocco        44.0      Morocco             MA
# 2  15906  Buenos Aires, Argentina        60.0    Argentina             AR
# 3  15964        Brussels, Belgium        46.0      Belgium             BE
# 4  15979             Milan, Italy        39.0        Italy             IT
#
#    city.id     city.name  city.keyword    school  school_id  state.id  \
# 0  31174.0     Melbourne     melbourne  le-wagon      10868       NaN
# 1  31119.0    Casablanca    casablanca  le-wagon      10868       NaN
# 2  31171.0  Buenos Aires  buenos-aires  le-wagon      10868       NaN
# 3  31125.0      Brussels      brussels  le-wagon      10868       NaN
# 4  31107.0         Milan         milan  le-wagon      10868       NaN
#
#   state.name state.abbrev state.keyword
# 0        NaN          NaN           NaN
# ...

# %%
# Raw courses (the code is as given - no change was made)

courses = pd.concat(courses_list)
courses.head()
# Out:
#                               courses    school  school_id
# 0            Data Science - Full-Time  le-wagon      10868
# 1  Web Development Course - Full-Time  le-wagon      10868
# 2  Web Development Course - Part-Time  le-wagon      10868
# 3            Data Science - Part-Time  le-wagon      10868
# 0          AI Programming with Python   udacity      11118

# %%
# Raw schools (the code is as given - no change was made)

# any data cleaning still missing here? take a look at the description
schools = pd.concat(schools_list)
schools.head()
# Out:
#                                              website  \
# 0                                    www.lewagon.com
# 0  www.udacity.com/?utm_source=switchup&utm_mediu...
# 0                                www.ironhack.com/en
# 0                                      appacademy.io
# 0  generalassemb.ly/?utm_medium=affiliate-lead-gl...
#
#                                          description  \
# 0  <span class="truncatable"><p>Le Wagon runs imm...
# 0  <span class="truncatable"><p>Udacity is a glob...
# 0  <span class="truncatable"><p>Ironhack is a glo...
# 0  <span class="truncatable"><p>App Academy is a ...
# 0  <span class="truncatable"><p>General Assembly ...
#
#                                              LogoUrl            school  \
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...          le-wagon
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...           udacity
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...          ironhack
# ...

# %%
# Code for the CLEANING of the LOCATIONS table --> locations_cleaned

locations_cleaned = locations[["country.name", "country.id"]]

locations_cleaned = locations_cleaned.rename(columns = {"country.name": "Country Name", "country.id": "Country.id"})

locations_cleaned = locations_cleaned.fillna(value = {"Country.id" : "0", "Country Name" : "Online", "city.id" : "0", "city.name" : "Online"}) 

locations_cleaned = locations_cleaned.sort_values(by = ["Country Name"])

locations_cleaned = locations_cleaned.drop_duplicates()

locations_cleaned = locations_cleaned.reset_index(drop=True)

locations_cleaned["Country Name"][28] = "Wales"

#country_unique = list(locations_cleaned["country.name"].unique())
                                     
locations_cleaned
# Out:
#             Country Name Country.id
# 0              Argentina         60
# 1              Australia         20
# 2                Belgium         46
# 3                 Brazil         42
# 4                 Canada          2
# 5                  Chile         22
# 6                  China         15
# 7                Denmark         47
# 8                England         61
# 9                 France         38
# 10               Germany         57
# 11             Indonesia         35
# 12                Israel          5
# 13                 Italy         39
# 14                 Japan         48
# 15                Mexico         29
# 16               Morocco         44
# 17           Netherlands         59
# 18                Norway         52
# 19                Online          0
# 20              Portugal         28
# 21             Singapore         56
# 22           South Korea         55
# 23                 Spain         12
# 24                Sweden         37
# ...

# %%
# Code to ADD the AVERAGE INCOME in each country in the table locations_cleaned

# Setp 1: Populate the list with the values from https://www.worlddata.info/average-income.php
# Same order as the countries!

list_avg_wages = [9400,46160,39800,7670,38980,12620,8750,53160,45170,35640,40790,3400,36390,28970,35050,7930,2680,44720,69350,0,19400,50090,28350,25550,46940,71870,8080,36540,75510,55280]
                  
# Grouped the locations by country - This step no longer needed since we drop the city in the
# locations_cleaned table. Just kept the code for you to see. We can remove after. 

#locations_unique = locations_cleaned.groupby(by = ["country.name"]).sum()

# Step 2: Add the average wages rate column in the locations_cleaned table

locations_cleaned["Average Wages"] = list_avg_wages

locations_cleaned
# Out:
#             Country Name Country.id  Average Wages
# 0              Argentina         60           9400
# 1              Australia         20          46160
# 2                Belgium         46          39800
# 3                 Brazil         42           7670
# 4                 Canada          2          38980
# 5                  Chile         22          12620
# 6                  China         15           8750
# 7                Denmark         47          53160
# 8                England         61          45170
# 9                 France         38          35640
# 10               Germany         57          40790
# 11             Indonesia         35           3400
# 12                Israel          5          36390
# 13                 Italy         39          28970
# 14                 Japan         48          35050
# 15                Mexico         29           7930
# 16               Morocco         44           2680
# ...

# %%
# Code for the CLEANING of the COURSES table --> courses_cleaned

courses_cleaned = courses[["school_id", "school", "courses"]]

courses_cleaned["courses"] = courses_cleaned["courses"].str.replace(" - Full-Time","") 

courses_cleaned["courses"] = courses_cleaned["courses"].str.replace(" - Part-Time","") 

courses_cleaned = courses_cleaned.drop_duplicates()

courses_cleaned = courses_cleaned.sort_values(by = ["school"])

courses_cleaned = courses_cleaned.reset_index(drop=True)

courses_cleaned = courses_cleaned.rename(columns = {"school_id": "School.id", "school": "School", "courses": "Courses"})


school_id = []

for i in courses_cleaned ["School.id"]:
    school_id.append(int(i))
    
len (courses_cleaned) # There are 76 courses

courses_cleaned
# Out:
#     School.id            School                             Courses
# 0       10525       app-academy  Software Engineer Track: In-Person
# 1       10525       app-academy     Software Engineer Track: Online
# 2       10525       app-academy                       Bootcamp Prep
# 3       10761  general-assembly           Front-End Web Development
# 4       10761  general-assembly                      Data Analytics
# ..        ...               ...                                 ...
# 71      11118           udacity                        Data Analyst
# 72      11118           udacity                     Computer Vision
# 73      11118           udacity                     Cloud Developer
# 74      11118           udacity                      Java Developer
# 75      11118           udacity                                 C++
#
# [76 rows x 3 columns]

# %%
# Code to ADD the PRICE of each course in the table courses_cleaned

# Setp 1: Populate the list with the PRICE from SWITCHUP on the course. Same order as the courses!

prices_country = [14250,16750,2500,3300,3300,13400,3300,3300,3300,3300,13400,13400,3300,2350,12550,3300,1700,1700,1700,10900,10000,10000,7000,8000,10900,7500,7000,7000,1150,1500,300,12600,12600,6300,6300,4600,2000,750,300,6650,7100,400,400,1200,900,600,900,1800,900,1800,900,900,1200,900,900,900,1200,1200,1800,900,1800,1200,900,1200,1200,900,1200,1200,1200,1200,1500,1200,900,1200,1200,1200]
                  
# Step 2: Add the course_price column in the courses_cleaned table

courses_cleaned["Price"] = prices_country

courses_cleaned = courses_cleaned.reset_index(drop=True)

courses_cleaned
# Out:
#     School.id            School                             Courses  Price
# 0       10525       app-academy  Software Engineer Track: In-Person  14250
# 1       10525       app-academy     Software Engineer Track: Online  16750
# 2       10525       app-academy                       Bootcamp Prep   2500
# 3       10761  general-assembly           Front-End Web Development   3300
# 4       10761  general-assembly                      Data Analytics   3300
# ..        ...               ...                                 ...    ...
# 71      11118           udacity                        Data Analyst   1200
# 72      11118           udacity                     Computer Vision    900
# 73      11118           udacity                     Cloud Developer   1200
# 74      11118           udacity                      Java Developer   1200
# 75      11118           udacity                                 C++   1200
#
# [76 rows x 4 columns]

# %%
# Code to ADD the SUCESS RATE of each SCHOOL in the table they gave us SCHOOLS.

# Setp 1: Populate the list with the SUCESS RATE from each school webpage. Same order as the schools!

success_rate = [100,1,89.0,95.0,91.4,1,78.0,100]
                  
# Step 2: Creation of a new table based on the SCHOOLS one. (Dropping no needed columns from table SCHOOLS)

schools_success = schools[["school", "school_id"]]
 
# Step 3: Add the sucess rate column in the NEW table - schools unique

# Added the average wages rate column

schools_success["sucess rate"] = success_rate

schools_success = schools_success.reset_index(drop=True)

schools_success = schools_success.rename(columns = {"school": "School", "school_id": "School.id", "sucess rate": "Success Rate"})

schools_success
# Out:
# <ipython-input-23-08f84014e3bd>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schools_success["sucess rate"] = success_rate
#               School  School.id  Success Rate
# 0           le-wagon      10868         100.0
# 1            udacity      11118           1.0
# 2           ironhack      10828          89.0
# 3        app-academy      10525          95.0
# 4   general-assembly      10761          91.4
# 5  hackwagon-academy      10792           1.0
# 6             nucamp      10923          78.0
# 7        springboard      11035         100.0

# %%
# Code for the CLEANING of the COMMENTS table --> comments_cleaned

comments = comments.rename(columns = {"id": "Student id", "curriculum": "Curriculum Rating", "jobSupport": "Job Support Rating", "school": "School"})

comments_cleaned = comments[["Student id","School", "Curriculum Rating", "Job Support Rating"]]#, 'Rating Mean'

comments_cleaned = comments_cleaned.rename(columns = {"Student id": "Student.id"})

comments_cleaned = comments_cleaned.fillna(value = {"Curriculum Rating": 1.0, "Job Support Rating": 1.0})

list_curriculum = []

list_job_support = []

mean_curriculum_jub_support = []

for i in comments_cleaned["Curriculum Rating"]:
    list_curriculum.append(float(i))
    
for a in comments_cleaned["Job Support Rating"]:
    list_job_support.append(float(a))

for b in range(len(list_curriculum)):
    mean_curriculum_jub_support.append((list_curriculum[b] + list_job_support[b]) / 2)

comments_cleaned["Rating Mean"] = mean_curriculum_jub_support

comments_cleaned = comments_cleaned.reset_index(drop=True)

comments_cleaned
# Out:
#       Student.id       School Curriculum Rating Job Support Rating  \
# 0         270744     le-wagon               5.0                3.0
# 1         270738     le-wagon               5.0                5.0
# 2         270579     le-wagon               5.0                5.0
# 3         270510     le-wagon               5.0                5.0
# 4         270151     le-wagon               5.0                5.0
# ...          ...          ...               ...                ...
# 7679      234894  springboard               5.0                5.0
# 7680      234877  springboard               5.0                5.0
# 7681      234838  springboard               4.0                3.0
# 7682      242681  springboard               5.0                5.0
# 7683      234178  springboard               5.0                4.0
#
#       Rating Mean
# 0             4.0
# 1             5.0
# 2             5.0
# 3             5.0
# 4             5.0
# ...           ...
# 7679          5.0
# ...
